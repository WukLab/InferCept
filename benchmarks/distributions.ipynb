# %%
import random
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 12, 4

s = np.random.normal(mu, sigma, 1000)
s = abs(s)
print(s)

plt.hist(s)
plt.show()
# Out:
# [13.72143783 12.17368708 10.85950547  9.77863708 10.52675526 13.80165649
#  10.31532763 13.00929602  7.51480669 11.12811688  4.94672872 17.37669705
#  13.00989884 12.35983768  9.91347301 16.37462676  9.31901582  6.36839766
#   8.61466366 14.03632526 13.0568656   4.20093513 13.96361626 14.48839544
#  15.1625907  13.13371005  0.76876996 13.51027295 11.1523901   9.1990576
#  13.86280945 11.93894635  9.76070253 10.32672356 10.94240418 15.22369574
#  12.34763046  6.88739502 11.31620568 16.15350125 10.86125593 19.17571212
#  17.4546555  10.61179816  5.89771937 14.57302052 22.08896662 16.7960373
#  10.4050081  17.51143457 13.14973705 19.27614337 20.64056218 16.04910141
#   8.62331215  7.52935325 10.85424905  5.86424233  4.11118246 13.04431
#  12.10339618 12.22420795 13.74278169  9.15643234  8.39022948  4.50629784
#   5.11768895  6.78319676  9.17390658  8.31876376 11.60107063 11.16469577
#  13.84144123 18.1475931  10.88026138 12.44014649 17.55172078 16.29734723
# ...

# %%
context = [1024] * 1000
total_tks = [0] * 1000
for i in range(1000):
    total_tks[i] += context[i]
    context[i]
